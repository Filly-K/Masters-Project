# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
data = pd.read_csv ('study1_all.csv')

# %%
data.head()
# Out:
#    Number\n  Age\n(Years)  Height \n(m)  Weight\n(kg)  BMI\n(kg/m^2)  \
# 0       1.0         23.73          1.90          76.1           21.0
# 1       5.0         27.62          1.75          68.8           22.0
# 2       7.0         24.39          1.73          81.0           27.0
# 3       8.0         22.87          1.82          77.8           24.0
# 4       9.0         23.92          1.75          72.7           23.6
#
#    Waist circumference \n(cm)  Systolic Blood Pressure at rest (mmHg)  \
# 0                        82.0                                   160.0
# 1                        80.0                                   126.0
# 2                        83.0                                   131.0
# 3                        82.0                                   139.0
# 4                        63.0                                   119.0
#
#    Diastolic Blood Pressure at rest (mmHg)  Heart rate at rest\n(bpm)  \
# 0                                     82.0                       55.0
# 1                                     75.0                       66.0
# 2                                     71.0                       74.0
# 3                                     78.0                       56.0
# 4                                     63.0                       71.0
#
#    Body fat %  ...  VT1 RER  VT2 FATox  VT2 CHOox  VT2 RER  VO2MAX \nFATox  \
# 0        12.8  ...      NaN        0.0       3.94     1.02             0.0
# 1        13.7  ...      NaN        0.0       2.82     1.10             0.0
# 2        11.4  ...      NaN        0.0       3.00     1.00             0.0
# 3        17.4  ...      NaN        0.0       2.94     1.06             0.0
# 4        18.1  ...      NaN        0.0       1.57     1.19             0.0
#
#    VO2MAX\nCHOox  VO2MAX\nRER  PFO \n(g/min)  PCHOox \n(g/min)  PEAK\nRER
# 0           3.06         1.16           0.95              5.59       1.19
# 1           1.39         1.27           0.48              3.41       1.30
# 2           2.00         1.20           0.70              5.00       1.30
# 3           2.68         1.14           0.54              4.75       1.18
# 4           0.58         1.35           0.36              2.63       1.45
#
# [5 rows x 68 columns]

# %%
data.columns
# Out:
# Index(['Number\n', 'Age\n(Years)', 'Height \n(m)', 'Weight\n(kg)',
#        'BMI\n(kg/m^2)', 'Waist circumference \n(cm)',
#        'Systolic Blood Pressure at rest (mmHg)',
#        'Diastolic Blood Pressure at rest (mmHg)', 'Heart rate at rest\n(bpm)',
#        'Body fat %', 'Skeletal muscle mass\n(kg)',
#        'Skeletal Muscle Mass Index\n(kg/m^2)', 'Visceral fat\n(Litres) ',
#        'Resting metabolic rate (kcal/day)', 'RQ', '%  Fat', '% Carbohydrate',
#        'Hand grip strength - dominant\n(kg)',
#        'Normative Percentiles \n(Wang et al., 2019)',
#        'Hand grip strength - non-dominant\n(kg)',
#        'Hand grip strength -  Combined Score\n(kg)',
#        'Normative Percentiles (Hoffmann et al., 2019)', 'Back strength\n(kg)',
#        'Back strength/kg', 'Absolute\nVO2 max\n(L/min)',
#        'Relative\nVO2 max\n(mL/kg/min)', 'VO2 max/\nSMM\n(mL/kg/min)',
#        'Max Aerobic\nPower \n(Watts)', 'MAP/BW (W/kg)', 'MAP/SMM (W/kg)',
#        'Normative Percentiles\n(Kaminsky et al., 2017)',
#        'Ventilatory threshold 1\n(mL/kg/min)', 'VT1/SMM\n(mL/kg/min)',
#        'VT 1 \n%Normal', 'VT 1 \n%VO2max',
#        'Ventilatory threshold 2\n(mL/kg/min)', 'VT2/SMM\n(mL/kg/min)',
#        'VT2\n%Normal', 'VT2\n%VO2max', 'Functional Threshold Power\n(Watts)',
#        'FTP/BW\n(W/kg)', 'FTP/SMM\n(W/kg)',
#        'Total Week vigorous PA\n(met.min) ',
#        'Total Week moderate PA\n(met.min)',
#        'Daily Active MET minutes M+V (met.min)',
#        'Time Spent Sitting  Per week\n(hours)', 'Calories Burned/Day\n(kcal)',
#        'Steps', 'Distance\n(km)', 'Minutes Sedentary',
#        'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories\n(kcal)',
#        'RMR FATox\n(g/min)', 'RMR CHOox', 'VT1 FATox', 'VT1 CHOox', 'VT1 RER',
#        'VT2 FATox', 'VT2 CHOox', 'VT2 RER', 'VO2MAX \nFATox', 'VO2MAX\nCHOox',
#        'VO2MAX\nRER', 'PFO \n(g/min)', 'PCHOox \n(g/min)', 'PEAK\nRER'],
#       dtype='object')

# %%
data_pca = data[[
       'Absolute\nVO2 max\n(L/min)',
       'Relative\nVO2 max\n(mL/kg/min)', 'VO2 max/\nSMM\n(mL/kg/min)',
       'Max Aerobic\nPower \n(Watts)', 'MAP/BW (W/kg)', 'MAP/SMM (W/kg)',
       'Normative Percentiles\n(Kaminsky et al., 2017)',
       'Ventilatory threshold 2\n(mL/kg/min)', 'VT2/SMM\n(mL/kg/min)',
       'VT2\n%Normal', 'VT2\n%VO2max', 'Functional Threshold Power\n(Watts)',
       'FTP/BW\n(W/kg)', 'FTP/SMM\n(W/kg)']]
data_pca
# Out:
#     Absolute\nVO2 max\n(L/min)  Relative\nVO2 max\n(mL/kg/min)  \
# 0                         3.65                           48.00
# 1                         2.89                           42.00
# 2                         4.13                           51.00
# 3                         3.03                           39.00
# 4                         2.76                           38.00
# 5                         3.02                           39.00
# 6                         5.17                           59.00
# 7                         3.58                           55.08
# 8                         3.10                           44.93
# 9                         3.60                           42.40
# 10                        3.92                           37.87
# 11                        3.82                           52.19
# 12                        3.70                           44.47
# 13                        3.44                           41.90
# 14                        3.83                           44.00
# 15                        3.17                           45.22
# 16                        2.85                           38.00
# 17                        4.26                           51.95
# 18                        3.79                           42.44
# 19                        2.36                           36.09
# 20                        2.92                           33.76
# 21                        1.78                           26.37
# 22                        3.12                           41.60
# 23                        2.58                           40.95
# 24                        3.70                           44.31
# 25                        3.41                           48.51
# 26                        3.03                           36.29
# 27                        3.12                           39.75
#
#     VO2 max/\nSMM\n(mL/kg/min)  Max Aerobic\nPower \n(Watts)  MAP/BW (W/kg)  \
# 0                       108.07                         280.0           3.68
# 1                        96.00                         210.0           3.05
# 2                       114.43                         300.0           3.70
# 3                        90.04                         230.0           2.96
# 4                        89.12                         210.0           2.89
# 5                       106.43                         215.0           2.77
# 6                       149.81                         420.0           4.79
# 7                       124.74                         290.0           4.46
# 8                       113.55                         250.0           3.62
# 9                       101.41                         240.0           2.83
# 10                      107.10                         270.0           2.61
# 11                      113.02                         280.0           3.83
# 12                      100.27                         260.0           3.13
# 13                      100.88                         260.0           3.17
# 14                      118.51                         260.0           2.99
# 15                      103.59                         250.0           3.57
# 16                       87.42                         220.0           2.93
# 17                      127.16                         310.0           3.78
# 18                      104.12                         270.0           3.02
# 19                       88.06                         180.0           2.75
# 20                       86.90                         220.0           2.54
# 21                       78.41                         170.0           2.52
# 22                      115.56                         230.0           3.07
# 23                       89.58                         200.0           3.17
# 24                      113.85                         240.0           2.87
# 25                      117.99                         250.0           3.56
# 26                       97.74                         230.0           2.75
# 27                      109.86                         205.0           2.61
#
#     MAP/SMM (W/kg)  Normative Percentiles\n(Kaminsky et al., 2017)  \
# 0             8.28                                            70.0
# 1             6.98                                            50.0
# 2             8.31                                            75.0
# 3             6.82                                            40.0
# 4             6.77                                            35.0
# 5             7.57                                            40.0
# 6            12.17                                            95.0
# 7            10.10                                            85.0
# 8             9.16                                            60.0
# 9             6.76                                            50.0
# 10            7.38                                            35.0
# 11            8.28                                            80.0
# 12            7.05                                            60.0
# 13            7.62                                            50.0
# 14            8.05                                            60.0
# 15            8.17                                            60.0
# 16            6.75                                            40.0
# 17            9.25                                            80.0
# 18            7.42                                            50.0
# 19            6.72                                            30.0
# 20            6.55                                            20.0
# 21            7.49                                            25.0
# 22            8.52                                            90.0
# 23            6.94                                            50.0
# 24            7.38                                            60.0
# 25            8.65                                            70.0
# 26            7.42                                            30.0
# 27            7.22                                            40.0
#
#     Ventilatory threshold 2\n(mL/kg/min)  VT2/SMM\n(mL/kg/min)  VT2\n%Normal  \
# 0                                   41.0                 92.31          90.0
# 1                                   41.0                 93.71          94.0
# 2                                   42.0                 94.24          95.0
# 3                                   31.0                 71.57          71.0
# 4                                   29.0                 68.01          67.0
# 5                                   31.0                 84.60          80.0
# 6                                   53.0                134.57         129.0
# 7                                   39.0                 88.33          83.0
# 8                                   42.0                106.15          88.0
# 9                                   37.0                 88.49          86.0
# 10                                  29.0                 82.01          79.0
# 11                                  41.0                 88.79          86.0
# 12                                  38.0                 85.68          90.0
# 13                                  35.0                 84.27          79.0
# 14                                  30.0                 80.80          69.0
# 15                                  41.0                 93.92          89.0
# 16                                  24.0                 55.21          55.0
# 17                                  43.0                105.25         157.0
# 18                                  36.0                 88.32          83.0
# 19                                  32.0                 78.09          64.0
# 20                                  27.0                 69.51          64.0
# 21                                  22.0                 65.42          54.0
# 22                                  33.0                 91.67          87.0
# 23                                  29.0                 63.44          61.0
# 24                                  36.0                 92.49         142.0
# 25                                  40.0                 97.30          87.0
# 26                                  33.0                 88.89          83.0
# 27                                  26.0                 71.87          61.0
#
#     VT2\n%VO2max  Functional Threshold Power\n(Watts)  FTP/BW\n(W/kg)  \
# 0          85.00                                221.0            2.90
# 1          98.00                                185.0            2.69
# 2          82.00                                255.0            3.15
# 3          80.00                                170.0            2.19
# 4          77.00                                156.0            2.15
# 5          80.00                                166.0            2.14
# 6          89.00                                339.0            3.87
# 7          71.00                                250.0            3.85
# 8          93.00                                190.0            2.75
# 9          88.00                                220.0            2.59
# 10         75.00                                200.0            1.93
# 11         78.00                                210.0            2.87
# 12         85.00                                190.0            2.28
# 13         84.00                                210.0            2.56
# 14         68.18                                180.0            2.07
# 15         91.00                                200.0            2.85
# 16         63.00                                150.0            2.00
# 17         83.00                                260.0            3.17
# 18         84.00                                250.0            2.80
# 19         88.00                                150.0            2.29
# 20         80.00                                200.0            2.31
# 21         84.00                                150.0            2.22
# 22         80.00                                190.0            2.53
# 23         70.00                                130.0            2.06
# 24         81.00                                190.0            2.28
# 25         82.00                                210.0            2.99
# 26         90.00                                170.0            2.04
# 27         65.00                                135.0            1.72
#
#     FTP/SMM\n(W/kg)
# 0              6.54
# 1              6.15
# 2              7.06
# 3              5.04
# 4              5.03
# 5              5.85
# 6              9.83
# 7              8.71
# 8              6.96
# 9              6.20
# 10             5.46
# 11             6.21
# 12             5.15
# 13             6.16
# 14             5.57
# 15             6.54
# 16             4.60
# 17             7.76
# 18             6.87
# 19             5.60
# 20             5.95
# 21             6.61
# 22             7.04
# 23             4.51
# 24             5.85
# 25             7.27
# 26             5.48
# 27             4.75

# %%
from sklearn import preprocessing
data_scaled = preprocessing.scale(data_pca)
data_scaled = pd.DataFrame(data_scaled[:,:], columns=data_pca.columns)
data_scaled
# Out:
#     Absolute\nVO2 max\n(L/min)  Relative\nVO2 max\n(mL/kg/min)  \
# 0                     0.467413                        0.738509
# 1                    -0.706915                       -0.148208
# 2                     1.209094                        1.181867
# 3                    -0.490591                       -0.591567
# 4                    -0.907786                       -0.739353
# 5                    -0.506043                       -0.591567
# 6                     2.816070                        2.364156
# 7                     0.359252                        1.784835
# 8                    -0.382429                        0.284805
# 9                     0.390155                       -0.089094
# 10                    0.884609                       -0.758565
# 11                    0.730092                        1.357733
# 12                    0.544672                        0.216823
# 13                    0.142928                       -0.162987
# 14                    0.745544                        0.147364
# 15                   -0.274267                        0.327663
# 16                   -0.768721                       -0.739353
# 17                    1.409966                        1.322264
# 18                    0.683737                       -0.083182
# 19                   -1.525854                       -1.021625
# 20                   -0.660560                       -1.365966
# 21                   -2.422052                       -2.458106
# 22                   -0.351526                       -0.207323
# 23                   -1.185917                       -0.303384
# 24                    0.544672                        0.193178
# 25                    0.096573                        0.813879
# 26                   -0.490591                       -0.992067
# 27                   -0.351526                       -0.480727
#
#     VO2 max/\nSMM\n(mL/kg/min)  Max Aerobic\nPower \n(Watts)  MAP/BW (W/kg)  \
# 0                     0.173313                      0.670844       0.867272
# 1                    -0.636375                     -0.806520      -0.272719
# 2                     0.599959                      1.092948       0.903462
# 3                    -1.036188                     -0.384416      -0.435575
# 4                    -1.097904                     -0.806520      -0.562240
# 5                     0.063297                     -0.700994      -0.779381
# 6                     2.973344                      3.625571       2.875827
# 7                     1.291581                      0.881896       2.278689
# 8                     0.540926                      0.037688       0.758701
# 9                    -0.273458                     -0.173364      -0.670811
# 10                    0.108243                      0.459792      -1.068903
# 11                    0.505372                      0.670844       1.138698
# 12                   -0.349932                      0.248740      -0.127958
# 13                   -0.309012                      0.248740      -0.055578
# 14                    0.873656                      0.248740      -0.381289
# 15                   -0.127218                      0.037688       0.668226
# 16                   -1.211944                     -0.595468      -0.489860
# 17                    1.453921                      1.304000       1.048223
# 18                   -0.091664                      0.459792      -0.327004
# 19                   -1.169012                     -1.439676      -0.815572
# 20                   -1.246827                     -0.595468      -1.195569
# 21                   -1.816359                     -1.650728      -1.231759
# 22                    0.675762                     -0.384416      -0.236529
# 23                   -1.067046                     -1.017572      -0.055578
# 24                    0.561051                     -0.173364      -0.598431
# 25                    0.838773                      0.037688       0.650131
# 26                   -0.519651                     -0.384416      -0.815572
# 27                    0.293391                     -0.912046      -1.068903
#
#     MAP/SMM (W/kg)  Normative Percentiles\n(Kaminsky et al., 2017)  \
# 0         0.358128                                          0.7697
# 1        -0.722790                                         -0.2327
# 2         0.383073                                          1.0203
# 3        -0.855826                                         -0.7339
# 4        -0.897400                                         -0.9845
# 5        -0.232219                                         -0.7339
# 6         3.592568                                          2.0227
# 7         1.871414                                          1.5215
# 8         1.089827                                          0.2685
# 9        -0.905714                                         -0.2327
# 10       -0.390200                                         -0.9845
# 11        0.358128                                          1.2709
# 12       -0.664586                                          0.2685
# 13       -0.190645                                         -0.2327
# 14        0.166889                                          0.2685
# 15        0.266666                                          0.2685
# 16       -0.914029                                         -0.7339
# 17        1.164660                                          1.2709
# 18       -0.356941                                         -0.2327
# 19       -0.938973                                         -1.2351
# 20       -1.080324                                         -1.7363
# 21       -0.298737                                         -1.4857
# 22        0.557682                                          1.7721
# 23       -0.756049                                         -0.2327
# 24       -0.390200                                          0.2685
# 25        0.665774                                          0.7697
# 26       -0.356941                                         -1.2351
# 27       -0.523236                                         -0.7339
#
#     Ventilatory threshold 2\n(mL/kg/min)  VT2/SMM\n(mL/kg/min)  VT2\n%Normal  \
# 0                               0.874322              0.418347      0.223765
# 1                               0.874322              0.509570      0.394252
# 2                               1.020914              0.544105      0.436874
# 3                              -0.591607             -0.933060     -0.586050
# 4                              -0.884793             -1.165028     -0.756537
# 5                              -0.591607             -0.084032     -0.202454
# 6                               2.633436              3.171986      1.886015
# 7                               0.581136              0.159012     -0.074588
# 8                               1.020914              1.320154      0.138521
# 9                               0.287950              0.169438      0.053277
# 10                             -0.884793             -0.252795     -0.245075
# 11                              0.874322              0.188986      0.053277
# 12                              0.434543             -0.013660      0.223765
# 13                             -0.005235             -0.105535     -0.245075
# 14                             -0.738200             -0.331638     -0.671294
# 15                              0.874322              0.523254      0.181143
# 16                             -1.617757             -1.999069     -1.267999
# 17                              1.167507              1.261511      3.079426
# 18                              0.141357              0.158361     -0.074588
# 19                             -0.445014             -0.508221     -0.884403
# 20                             -1.177978             -1.067289     -0.884403
# 21                             -1.910942             -1.333791     -1.310621
# 22                             -0.298421              0.376645      0.095899
# 23                             -0.884793             -1.462807     -1.012268
# 24                              0.141357              0.430076      2.440099
# 25                              0.727729              0.743493      0.095899
# 26                             -0.298421              0.195502     -0.074588
# 27                             -1.324571             -0.913513     -1.012268
#
#     VT2\n%VO2max  Functional Threshold Power\n(Watts)  FTP/BW\n(W/kg)  \
# 0       0.462455                             0.535388        0.675333
# 1       2.053208                            -0.281058        0.276242
# 2       0.095358                             1.306476        1.150441
# 3      -0.149374                            -0.621245       -0.673975
# 4      -0.516470                            -0.938751       -0.749992
# 5      -0.149374                            -0.711961       -0.768997
# 6       0.951917                             3.211518        2.518753
# 7      -1.250664                             1.193081        2.480744
# 8       1.441380                            -0.167663        0.390268
# 9       0.829552                             0.512709        0.086198
# 10     -0.761202                             0.059128       -1.168088
# 11     -0.394105                             0.285918        0.618320
# 12      0.462455                            -0.167663       -0.502936
# 13      0.340089                             0.285918        0.029185
# 14     -1.595736                            -0.394454       -0.902027
# 15      1.196649                             0.059128        0.580311
# 16     -2.229590                            -1.074826       -1.035057
# 17      0.217723                             1.419872        1.188450
# 18      0.340089                             1.193081        0.485289
# 19      0.829552                            -1.074826       -0.483932
# 20     -0.149374                             0.059128       -0.445923
# 21      0.340089                            -1.074826       -0.616962
# 22     -0.149374                            -0.167663       -0.027828
# 23     -1.373030                            -1.528407       -0.921031
# 24     -0.027008                            -0.167663       -0.502936
# 25      0.095358                             0.285918        0.846372
# 26      1.074283                            -0.621245       -0.959040
# 27     -1.984858                            -1.415012       -1.567179
#
#     FTP/SMM\n(W/kg)
# 0          0.252160
# 1         -0.076823
# 2          0.690805
# 3         -1.013161
# 4         -1.021596
# 5         -0.329887
# 6          3.027432
# 7          2.082659
# 8          0.606450
# 9         -0.034646
# 10        -0.658871
# 11        -0.026210
# 12        -0.920371
# 13        -0.068388
# 14        -0.566081
# 15         0.252160
# 16        -1.384322
# 17         1.281289
# 18         0.530531
# 19        -0.540774
# 20        -0.245533
# 21         0.311209
# 22         0.673934
# 23        -1.460241
# 24        -0.329887
# 25         0.867950
# 26        -0.642000
# 27        -1.257790

# %%
wcss =[]

for i in range(1,12):
    kmeans = KMeans(i)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)
    
wcss
# Out:
# [392.0,
#  219.50413287519103,
#  144.26604276825847,
#  115.57632054313571,
#  97.52534506003421,
#  86.99128770140493,
#  76.10261790368679,
#  63.55475868461348,
#  52.68660470499878,
#  44.810579179325806,
#  38.177666756438555]

# %%
plt.plot(range(1,12),wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
clustering_kmeans = KMeans(n_clusters=3, precompute_distances="auto")
data_scaled['clusters'] = clustering_kmeans.fit_predict(data_scaled)
data_scaled['clusters']
# Out:
# C:\Users\filip\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:932: FutureWarning: 'precompute_distances' was deprecated in version 0.23 and will be removed in 0.25. It has no effect
#   warnings.warn("'precompute_distances' was deprecated in version "
# 0     0
# 1     0
# 2     0
# 3     1
# 4     1
# 5     1
# 6     2
# 7     2
# 8     0
# 9     0
# 10    1
# 11    0
# 12    0
# 13    0
# 14    1
# 15    0
# 16    1
# 17    2
# 18    0
# 19    1
# 20    1
# 21    1
# 22    0
# 23    1
# 24    0
# 25    0
# 26    1
# 27    1
# Name: clusters, dtype: int32

# %%
pca_num_components = 2

reduced_data = PCA(n_components=pca_num_components).fit_transform(data_scaled)
results = pd.DataFrame(reduced_data,columns=['pca1','pca2'])
results
sns.scatterplot(x="pca1", y="pca2", hue=data_scaled['clusters'], data=results)
plt.title('All Subjects - Aerobic Fitness PCA')
plt.show()
